# %%
# Out:
# Requirement already satisfied: easyocr in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (2.2.2)
# Requirement already satisfied: torchvision>=0.5 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.17.2)
# Requirement already satisfied: opencv-python-headless in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: numpy in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (10.3.0)
# Requirement already satisfied: scikit-image in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (2.0.3)
# Requirement already satisfied: pyclipper in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (4.11.0)
# Requirement already satisfied: sympy in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (2024.3.1)
# Requirement already satisfied: six in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (24.0)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
pip install matplotlib
pip install numpy
# Out:
#   Cell In[1], line 1
#     pip install opencv-python
#         ^
# SyntaxError: invalid syntax

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ragha\appdata\roaming\python\python312\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ragha\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# C:\Users\ragha\AppData\Local\Temp\ipykernel_10712\3866562534.py:1: SyntaxWarning: invalid escape sequence '\j'
#   IMAGE_PATH = 'D:\jupyter\ocr\img.png.png'

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[288, 112], [324, 112], [324, 144], [288, 144]], 'Al', 0.39281037229784144),
#  ([[277, 195], [335, 195], [335, 233], [277, 233]], 'ML', 0.99987406753927),
#  ([[251, 358], [356, 358], [356, 411], [251, 411]],
#   'Deep',
#   0.9999893307685852),
#  ([[226, 406], [382, 406], [382, 456], [226, 456]],
#   'Learning',
#   0.9999901797643241)]

# %%
IMAGE_PATH = 'D:\jupyter\ocr\five.png.png'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# C:\Users\ragha\AppData\Local\Temp\ipykernel_10712\1491538304.py:1: SyntaxWarning: invalid escape sequence '\j'
#   IMAGE_PATH = 'D:\jupyter\ocr\five.png.png'

# %%
IMAGE_PATH = 'six.png'

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[47, 21], [103, 21], [103, 37], [47, 37]], 'FaNciFvL', 0.3481781395731126),
#  ([[116, 8], [206, 8], [206, 39], [116, 39]], 'kok cngy', 0.3624387436700183),
#  ([[3, 33], [58, 33], [58, 70], [3, 70]], 'Psst &', 0.11069857115522003),
#  ([[85, 43], [151, 43], [151, 79], [85, 79]], '8ltse', 0.10575999809403033),
#  ([[162, 36], [220, 36], [220, 66], [162, 66]], 'MNDED', 0.2462400648477107),
#  ([[68, 80], [162, 80], [162, 104], [68, 104]],
#   'quick bvwh',
#   0.5357501155383797),
#  ([[111, 111], [139, 111], [139, 127], [111, 127]],
#   'Ine ',
#   0.2503609295786962),
#  ([[136, 104], [180, 104], [180, 136], [136, 136]],
#   'Yesy =',
#   0.1279895464240386),
#  ([[13, 147], [71, 147], [71, 185], [13, 185]], '"Gipul', 0.13456124884025886),
#  ([[86, 142], [225, 142], [225, 197], [86, 197]],
#   'S Axk',
#   0.06163143365232271),
#  ([[40, 181], [137, 181], [137, 202], [40, 202]],
#   'Wnbnedictahla',
#   0.16656272111372547)]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
img = cv2.putText(img, text, top_left, font, .5, (255,255,255), cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
img = cv2.imread(IMAGE_PATH)
for detection in result:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 2)
    img = cv2.putText(img, text, top_left, font, .3, (0,0,0), 20)

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
